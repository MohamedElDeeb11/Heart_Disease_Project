# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 🔮 التحليل غير المشرف\n",
    "## اكتشاف الأنماط باستخدام التجميع"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\n",
    "import numpy as np\n",
    "import matplotlib.pyplot as plt\n",
    "import sys\n",
    "import os\n",
    "\n",
    "sys.path.append('../src')\n",
    "from unsupervised_learning import UnsupervisedLearning\n",
    "\n",
    "print(\"🔮 بدء التحليل غير المشرف...\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# تحميل البيانات الكاملة\n",
    "df = pd.read_csv('../data/heart_disease_cleaned.csv')\n",
    "print(f\"📊 البيانات للتحليل: {df.shape}\")\n",
    "df.head()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# تهيئة محلل التعلم غير المشرف\n",
    "unsupervised = UnsupervisedLearning()\n",
    "\n",
    "# تطبيق خطة التحليل الكاملة\n",
    "results = unsupervised.complete_unsupervised_pipeline(df)\n",
    "print(\"🎉 تم الانتهاء من التحليل غير المشرف\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# تحليل النتائج\n",
    "print(f\"🎯 العدد الأمثل للتجمعات: {results['optimal_k']}\")\n",
    "print(\"✅ تم اكتشاف الأنماط في البيانات بنجاح\")"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 4
}
