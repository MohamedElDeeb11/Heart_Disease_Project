# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 📊 معالجة البيانات - أمراض القلب\n",
    "## تنظيف وتحضير البيانات للتحليل"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\n",
    "import numpy as np\n",
    "import matplotlib.pyplot as plt\n",
    "import seaborn as sns\n",
    "import sys\n",
    "import os\n",
    "\n",
    "sys.path.append('../src')\n",
    "from data_preprocessing import DataPreprocessor\n",
    "\n",
    "print(\"🚀 بدء معالجة بيانات أمراض القلب...\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# تحميل البيانات\n",
    "processor = DataPreprocessor()\n",
    "df = processor.load_data('../data/heart_disease.csv')\n",
    "df.head()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# استكشاف البيانات\n",
    "processor.explore_data(df)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# معالجة القيم المفقودة\n",
    "df_clean = processor.handle_missing_values(df)\n",
    "df_clean.head()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# ترميز المتغيرات الفئوية\n",
    "df_encoded = processor.encode_categorical(df_clean)\n",
    "df_encoded.head()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# توحيد المقاييس\n",
    "df_final = processor.scale_features(df_encoded)\n",
    "print(\"✅ تم الانتهاء من معالجة البيانات\")\n",
    "df_final.head()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# حفظ البيانات المعالجة\n",
    "df_final.to_csv('../data/heart_disease_cleaned.csv', index=False)\n",
    "print(\"💾 تم حفظ البيانات المعالجة\")"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 4
}
