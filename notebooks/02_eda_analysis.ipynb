# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 🔍 التحليل الاستكشافي للبيانات\n",
    "## فهم البيانات واستكشاف الأنماط"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\n",
    "import numpy as np\n",
    "import matplotlib.pyplot as plt\n",
    "import seaborn as sns\n",
    "import sys\n",
    "import os\n",
    "\n",
    "sys.path.append('../src')\n",
    "from eda_analysis import EDAAnalysis\n",
    "\n",
    "print(\"🔍 بدء التحليل الاستكشافي...\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# تحميل البيانات المعالجة\n",
    "df = pd.read_csv('../data/heart_disease_cleaned.csv')\n",
    "print(f\"📊 شكل البيانات: {df.shape}\")\n",
    "df.head()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# إنشاء محلل البيانات\n",
    "analyzer = EDAAnalysis()\n",
    "\n",
    "# تحليل المتغير المستهدف\n",
    "target_dist = analyzer.plot_target_distribution(df)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# مصفوفة الارتباط\n",
    "correlation_matrix = analyzer.plot_correlation_matrix(df)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# تحليل PCA\n",
    "pca_model, X_pca, explained_variance = analyzer.perform_pca_analysis(df)\n",
    "print(f\"🎯 عدد المكونات الرئيسية المطلوبة: {np.argmax(explained_variance >= 0.95) + 1}\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# تقرير تحليلي شامل\n",
    "eda_results = analyzer.generate_eda_report(df)\n",
    "print(\"🎉 تم الانتهاء من التحليل الاستكشافي\")"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 4
}
