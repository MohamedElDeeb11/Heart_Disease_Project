# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 🎯 اختيار الميزات المهمة\n",
    "## تحديد أهم الميزات للتوقع"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\n",
    "import numpy as np\n",
    "import matplotlib.pyplot as plt\n",
    "import seaborn as sns\n",
    "import sys\n",
    "import os\n",
    "\n",
    "sys.path.append('../src')\n",
    "from feature_selection import FeatureSelector\n",
    "\n",
    "print(\"🎯 بدء اختيار الميزات...\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# تحميل البيانات\n",
    "df = pd.read_csv('../data/heart_disease_cleaned.csv')\n",
    "print(f\"📊 البيانات الأصلية: {df.shape}\")\n",
    "df.head()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# تهيئة محدد الميزات\n",
    "selector = FeatureSelector()\n",
    "\n",
    "# اختيار الميزات النهائية\n",
    "selected_features = selector.select_final_features(\n",
    "    df.drop(columns=['target']), \n",
    "    df['target'], \n",
    "    top_k=8\n",
    ")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# الحصول على البيانات المختزلة\n",
    "reduced_df = selector.get_reduced_dataset(df)\n",
    "reduced_df.head()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# حفظ البيانات المختزلة\n",
    "reduced_df.to_csv('../data/heart_disease_reduced.csv', index=False)\n",
    "print(\"💾 تم حفظ البيانات المختزلة\")"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 4
}
