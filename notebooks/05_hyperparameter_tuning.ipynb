# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# ⚙️ ضبط معاملات النماذج\n",
    "## تحسين أداء النماذج باستخدام Grid Search"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\n",
    "import numpy as np\n",
    "import matplotlib.pyplot as plt\n",
    "import sys\n",
    "import os\n",
    "\n",
    "sys.path.append('../src')\n",
    "from hyperparameter_tuning import HyperparameterTuner\n",
    "\n",
    "print(\"⚙️ بدء ضبط المعاملات...\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# تحميل البيانات والنتائج الأساسية\n",
    "df = pd.read_csv('../data/heart_disease_reduced.csv')\n",
    "baseline_results = pd.read_csv('../results/model_results.csv')\n",
    "\n",
    "print(f\"📊 البيانات: {df.shape}\")\n",
    "print(\"📈 النتائج الأساسية:\")\n",
    "baseline_results[['Model', 'Accuracy', 'F1-Score']]"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# تهيئة معدل المعاملات\n",
    "tuner = HyperparameterTuner()\n",
    "\n",
    "# ضبط المعاملات\n",
    "tuning_results, comparison_df = tuner.complete_tuning_pipeline(df, baseline_results)\n",
    "comparison_df"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# تحليل التحسن\n",
    "if comparison_df is not None:\n",
    "    total_improvement = comparison_df['Improvement'].sum()\n",
    "    print(f\"📊 إجمالي التحسن: {total_improvement:.4f}\")\n",
    "    print(\"✅ تم حفظ النماذج المظبوطة في مجلد models/\")"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 4
}
