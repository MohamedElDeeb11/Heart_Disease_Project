# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 🤖 تدريب نماذج التعلم الآلي\n",
    "## تدريب وتقييم النماذج المختلفة"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\n",
    "import numpy as np\n",
    "import matplotlib.pyplot as plt\n",
    "import seaborn as sns\n",
    "import sys\n",
    "import os\n",
    "\n",
    "sys.path.append('../src')\n",
    "from model_training import ModelTrainer\n",
    "\n",
    "print(\"🤖 بدء تدريب النماذج...\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# تحميل البيانات المختزلة\n",
    "df = pd.read_csv('../data/heart_disease_reduced.csv')\n",
    "print(f\"📊 البيانات للتدريب: {df.shape}\")\n",
    "df.head()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# تهيئة مدرب النماذج\n",
    "trainer = ModelTrainer()\n",
    "\n",
    "# تدريب جميع النماذج\n",
    "results_df = trainer.train_complete_pipeline(df)\n",
    "results_df"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# عرض أفضل النماذج\n",
    "best_models = results_df.nlargest(3, 'Accuracy')\n",
    "print(\"🏆 أفضل 3 نماذج:\")\n",
    "for _, model in best_models.iterrows():\n",
    "    print(f\"   {model['Model']}: دقة {model['Accuracy']:.4f}\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# حفظ النتائج\n",
    "results_df.to_csv('../results/model_results.csv', index=False)\n",
    "print(\"💾 تم حفظ نتائج التدريب\")"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 4
}
